# %% [markdown]
# #Sequence Alignment
# + Global: Needle
# + Local: Smith-Waterman
# + Terms
#  + Matches
#  + Mismatch
#  + Gaps

# %% [markdown]
# ![aligngap.png](data:image/png;base64,...)

# %% [markdown]
# ![localvsglobalalignment.jpg](data:image/jpeg;base64,...)

# %%
import skbio.alignment as align
from skbio import DNA,RNA,Protein,Sequence

# %%
# Methods
dir(align)
# Out:
# ['AlignmentStructure',
#  'StripedSmithWaterman',
#  'TabularMSA',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_indexing',
#  '_pairwise',
#  '_repr',
#  '_ssw_wrapper',
#  '_tabular_msa',
#  'global_pairwise_align',
#  'global_pairwise_align_nucleotide',
#  'global_pairwise_align_protein',
#  'local_pairwise_align',
#  'local_pairwise_align_nucleotide',
#  'local_pairwise_align_protein',
#  'local_pairwise_align_ssw',
#  'make_identity_substitution_matrix']

# %%
seq1 = DNA("ACTATCAGT")
seq2 = DNA("ACTTACAGT")
seq3 = DNA("ACTTAC")

# %%
# Local Alignment StripedSmithWaterman
alignment,score,start_end_positions = align.local_pairwise_align_ssw(seq1,seq2)

# %%
# Score of Alignment
print(score)
# Out:
# 8

# %%
# Get the alignment
alignment
# Out:
# TabularMSA[DNA]
# ---------------------
# Stats:
#     sequence count: 2
#     position count: 4
# ---------------------
# CAGT
# CAGT

# %%
# Get positions
start_end_positions
# Out:
# [(5, 8), (5, 8)]
